# %%
class Node():
    def __init__(self, value):
        self.data = value
        self.ref = None
    def reference(self, ref):
        self.ref = ref
    def setval(self, value):
        self.data = value

# %%
class Linked_list():
    def __init__(self):
        self.head = None
        self.nodes = 0
    def add_end(self, element):
        temp = self.head
        self.nodes += 1
        print(f"Number of nodes in the list: {self.nodes}")
        element = Node(element)
        if self.head is None:
            self.head = element
        else:
            temp = self.head
            for i in range(self.nodes-1):
                if temp.ref is None:
                    temp.ref = element
                temp = temp.ref
    def add_begining(self, element):
        temp = self.head
        self.nodes += 1
        self.head = Node(element)
        if temp is not None:
            self.head.ref = temp
    def traverse_list(self):
        temp = self.head
        if temp is None:
            print("Linked list is empty.")
        else:
            for i in range(self.nodes):
                print(temp.data, end = " ")
                temp = temp.ref
            print("")
    def search(self, element):
        nodes = []
        c_node = 1
        temp = self.head
        if temp is None:
            print("Linked list is empty.")
        else:
            for i in range(self.nodes):
                if temp.data == element:
                    nodes.append(c_node)
                c_node += 1
                temp = temp.ref
        if (len(nodes) == 1):
            return nodes[0]
        elif (len(nodes) > 1):
            return nodes
        else:
            return -1
    def delete_node(self, node):
        temp1 = self.head
        if temp1 is None:
            print("Linked list is empty")
        elif (node - 2 < 0):
            self.head = temp1.ref
        else:
            for i in range(node-2):
                temp1 = temp1.ref
            temp2 = temp1.ref.ref
            temp1.ref = temp2
            self.nodes -= 1
    def delete_element(self, element):
        count = 0
        node = self.search(element)
        if node == -1:
            print("Element not found in list.")
        else:
            if isinstance(node, int):
                self.delete_node(node)
                print("Element deleted succesfully.")
            else:
                print(f"{len(node)} occurances of elements found. What would you like to do?")
                choice = int(input("Delete all (1)\nDelete specific occurances (2)"))
                while choice not in range(1, 3):
                    print("Invalid input.")
                    choice = int(input("Delete all (1)\nDelete specific occurances (2)"))
                if choice == 1:
                    for n in node:
                        self.delete_node(n- count)
                        count += 1
                    print("All occurances deleted succesfully.")
                else:
                    print(f"Elements occur at nodes: {node}")
                    nodes = list(map(int, input("Enter the nodes u want to delete: ").split()))
                    print(nodes)
                    while not (set(nodes).issubset(set(node))):
                        print("Nodes specified not in range.")
                        nodes = list(map(int, input("Enter the nodes u want to delete: ").split()))
                    for n in nodes:
                        self.delete_node(n - count)
                        count += 1
                    print("Selected nodes deleted.")

# %%
List = Linked_list()

while True:
    choice = input("Operations:\nAdd element from end(1)\nView list(2)\nAdd element from beginning(3)\nSearch for an element(4)\nDelete a node(5)\nDelete an element from List(6)\nExit(7)")
    try:
        choice = int(choice)
    except:
        print("Input entered is not an integer.")
        continue
    if choice == 1:
        element = int(input("Enter element to add at end: "))
        List.add_end(element)
        print(f"Element {element} added to end of List successfully.")
    elif choice == 2:
        print("Linked list contains: ", end = '')
        List.traverse_list()
    elif choice == 3:
        element = int(input("Enter element to add at beginning: "))
        List.add_begining(element)
        print(f"Element {element} added to beginning successfully.")
    elif choice == 4:
        element = int(input("Enter element to search in linked list: "))
        node = List.search(element)
        if isinstance(node, list):
            print(f"Element stored in nodes {node}.")
        elif node == -1:
            print("Element not found.")
        else:
            print(f"Element stored in node {node}.")
    elif choice == 5:
        print(f"Available nodes: {List.nodes}")
        node = int(input("Enter node to delete: "))
        while node < 1 or node > List.nodes:
            print("Node entered not available.")
            node = int(input("Enter node to delete: "))
        List.delete_node(node)
        print(f"Node {node} deleted succesfully.")  
    elif choice == 6:
        element = int(input("Enter element you want to delete: "))
        List.delete_element(element)          
    elif choice == 7:
        print("Exiting.")
        break
# Out:
# Number of nodes in the list: 1
# Element 5 added to end of List successfully.
# Linked list contains: 5
# Number of nodes in the list: 2
# Element 10 added to end of List successfully.
# Linked list contains: 5 10
# Linked list contains: 5 10
# Number of nodes in the list: 3
# Element 15 added to end of List successfully.
# Linked list contains: 5 10 15
# Linked list contains: 5 10 15
# Linked list contains: 5 10 15
# Element 20 added to beginning successfully.
# Linked list contains: 20 5 10 15
# Element 15 added to beginning successfully.
# Linked list contains: 15 20 5 10 15
# Element stored in node 2.
# Element deleted succesfully.
# Linked list contains: 15 5 10 15
# 2 occurances of elements found. What would you like to do?
# Invalid input.
# Invalid input.
# Invalid input.
# Elements occur at nodes: [1, 4]
# [4]
# Selected nodes deleted.
# Linked list contains: 15 5 10
# Linked list contains: 15 5 10
# Exiting.
